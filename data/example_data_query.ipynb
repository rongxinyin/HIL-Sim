# %%
import os
import sys
import datetime
import pytz
if '../' not in sys.path:
    sys.path.append('../')

# %%
from flexlab.db_layer.db_interface import DB_Interface

# %%
tz_local = pytz.timezone("US/Pacific")
tz_utc = pytz.timezone("UTC")

# %%
db = DB_Interface(config_file='db_interface_config_template_metrics.yaml')

# %%
et_utc = tz_utc.localize(datetime.datetime.utcnow())
et_local = et_utc.astimezone(tz_local)

st_local = et_local - datetime.timedelta(days=1)

# %%
st_local
# Out:
# datetime.datetime(2021, 8, 29, 9, 22, 32, 198307, tzinfo=<DstTzInfo 'US/Pacific' PDT-1 day, 17:00:00 DST>)

# %%
db.get_data(st=st_local, et=et_local, cell='1a') # cell can be '1a' or '1b'
# Out:
#                      desk1_plug_power  desk2_plug_power  desk3_plug_power  desk4_plug_power  desk5_plug_power  desk6_plug_power  desk3_light_power  desk4_light_power  desk2_light_power  ...  1A-VAV3-DischargeAirTemp  1A-VAV1-DischargeAirflow  1A-VAV2-DischargeAirflow  1A-VAV3-DischargeAirflow   1A-ASAM-1   1A-ARAM-1   1A-SAT-1  1A-OADA-1-POSN  1A-RADA-1-POSN
# time                                                                                                                                                                                      ...
# 2021-08-29 09:30:00        241.334986        149.216186         89.377700        227.297900        226.148657        229.589671          86.088714          85.948929          87.905714  ...                     63.34                     67.96                     67.39                    103.93  434.735714   -0.646600  16.346943       94.889771       -0.412371
# 2021-08-29 09:45:00        240.582060        149.338900         89.918713        227.472573        226.844680        229.626653          86.056500          85.912960          87.755927  ...                     60.09                     68.38                     68.00                    105.30  433.225333   -0.625193  14.477487       94.886767       -0.408193
# 2021-08-29 10:00:00        240.677580        149.110213         90.291533        227.437620        226.891660        228.997933          86.043373          86.061120          87.745193  ...                     58.62                     68.44                     68.36                    104.27  428.977333   -0.662840  12.844587       94.886447       -0.410633
# 2021-08-29 10:15:00        241.993933        149.174860         90.278920        228.048713        226.953000        228.692720          86.024453          86.249807          87.900720  ...                     56.20                     69.43                    145.70                    186.00  672.850000   16.684847  12.031453       94.883453       -0.408380
# 2021-08-29 10:30:00        239.059020        148.661687         90.071280        226.831820        226.058820        229.224933          86.015720          86.416833          87.967880  ...                     55.34                     68.42                    133.53                    188.00  651.014000   23.289573  11.689887       94.294040        0.167440
# ...                               ...               ...               ...               ...               ...               ...                ...                ...                ...  ...                       ...                       ...                       ...                       ...         ...         ...        ...             ...             ...
# 2021-08-30 08:30:00        186.315660        148.482793         34.867020         34.721707         35.676667         34.834673          86.473667          85.844347          88.088460  ...                     66.50                     68.06                     68.62                    106.16  395.429333  167.331880  18.369020       94.875353       26.732893
# 2021-08-30 08:45:00        185.541427        147.518493         37.073673         34.265093         35.709747         34.974507          86.207860          85.940480          88.044953  ...                     66.42                     68.01                     68.18                    106.59  394.691333  171.316320  18.346353       94.871647       27.612007
# 2021-08-30 09:00:00        184.776240        147.661300         34.839640         34.351660         35.393800         34.991993          86.145020          85.977113          87.974667  ...                     66.49                     68.39                     68.96                    103.15  392.638000  166.739620  18.402033       94.873187       27.558407
# 2021-08-30 09:15:00        236.780013        148.130360         86.193400        214.042960        212.252953        223.274820          86.107907          85.817167          87.863487  ...                     66.61                     67.52                     68.34                    106.18  395.201333  161.410047  18.491593       94.872493       25.905060
# 2021-08-30 09:30:00        240.011075        147.071462         89.351125        225.232025        223.591763        227.579275          86.189887          85.862550          87.729550  ...                       NaN                       NaN                       NaN                       NaN  395.330000  141.172000  18.557900       94.869763       23.782950
#
# [97 rows x 46 columns]

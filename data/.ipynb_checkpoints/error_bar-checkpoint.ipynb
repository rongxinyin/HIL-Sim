# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('error_data.csv',index_col=0)
print(df)
df=df.drop(columns='RA Damper (position)')
# Out:
#                                           NMBE  CV(RMSE)
# Variable Name
# VAV north Discharge Air flowrate (cfm)  -8.600      37.8
# VAV Core Discharge Air flowrate (cfm)   -0.900      15.5
# VAV South Discharge Air flowrate (cfm)   0.700      24.4
# VAV north Discharge Air temp (degF)     -4.100       8.7
# VAV Core Discharge Air temp (degF)      -0.800       3.8
# VAV South Discharge Air temp (degF)     -0.300       8.6
# VAV North Zone Air temp (degF)           0.000       1.4
# VAV Core Zone Air temp (degF)           -1.400       1.8
# VAV South Zone Air temp (degF)          -1.100       2.7
# AHU SAT (deg F)                         -0.008       2.5
# Fan supply airflow (cfm)               -16.500      25.0
# Fan power (W)                           14.100      15.5
# OA Damper (position)                     0.500      16.2
# RA Damper (position)                    15.100      45.6
# Chiller cooling Load (W)                 3.800      21.7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-197c50771c24> in <module>
#       1 df=pd.read_csv('error_data.csv',index_col=0)
#       2 print(df)
# ----> 3 df=df.drop(columns='RA Damper (position)')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['RA Damper (position)'] not found in axis"

# %%
df.plot.bar(rot=0,figsize=(15,8))
plt.title('Hourly Error Plot',fontsize=20)
plt.xlabel('Variable Name',fontsize=15)
plt.ylabel('Hourly Error (%)',fontsize=15)
plt.legend(fontsize=13)
plt.xticks(rotation='vertical',fontsize=12)
plt.show()
